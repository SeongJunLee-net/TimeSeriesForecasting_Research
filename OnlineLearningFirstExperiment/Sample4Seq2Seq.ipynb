# %% [markdown]
# <font color = blue><font size = 6> 실험설명 </font></font><br>
# Pytorch의 모델 구성의 기본을 study하면서 seq2seq의 many to one을 구현해볼 것이다 이를 위해서는 Decoder에 Encoder의 cell과 hidden state와 함께 마지막 data를 넣어주어야 한다 <br>
# 여기서 진행할 실험은
# <font color = blue>정답 값이 들어올 때 훈련없이 그 정답 값을 이용해서 다음 값을 예측한 것이다</font><br>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
import torch
import torch.nn as nn
from pytorch_forecasting.metrics import SMAPE
from torch.utils.data import DataLoader,TensorDataset
from torch import FloatTensor
from torch.optim import Adam

# %%
use_col = ['volumn']
data = pd.read_csv('../traffic/data/4.csv',usecols=use_col)
data.rename({'volumn':'value'},axis=1,inplace=True)
data['value'] = data['value'] * 8 / 1000000
data
# Out:
#           value
# 0      0.838168
# 1      0.814640
# 2      0.801280
# 3      0.803872
# 4      0.780264
# ...         ...
# 38875  0.729952
# 38876  0.710640
# 38877  0.736008
# 38878  0.705272
# 38879  0.728872
#
# [38880 rows x 1 columns]

# %%
import configparser
import os
config = configparser.ConfigParser()
config['1step_seq2seq']= {
    'input_size':1,
    'num_layers':1,
    'hidden_size':8,
}
with open('1step_seq2seq','w') as f:
    config.write(f)
    
config.read(os.getcwd()+os.sep+'1step_seq2seq')
# Out:
# ['/hdd_1/sjlee/Paper_Project/1step_seq2seq']

# %%
class Encoder(nn.Module):
    def __init__(self,configs):
        super(Encoder,self).__init__()
        self.input_size = int(configs['1step_seq2seq']['input_size'])
        # input의 feature dimension을 넣어주어야 한다
        self.hidden_size = int(configs['1step_seq2seq']['hidden_size'])
        # 내부에서 feature dimension을 어떻게 바꿔주고 싶은지 넣어주면 된다
        # 가령 mxn matrix가 입력으로 들어왔을때 hidden size를 h라 한다면 mxh의 크기로 바꾼다
        self.num_layers = int(configs['1step_seq2seq']['num_layers'])
        self.lstm = nn.LSTM(input_size=self.input_size,hidden_size = self.hidden_size,
                           num_layers = self.num_layers,batch_first = True)

    
    def forward(self,x):
        lstm_out,hidden = self.lstm(x) 
        #lstm의 output으로 나오는 hidden_state는 마지막 hidden_state값이다
        # hidden에는 튜플형태로 hidden_state와 cell_state가 둘다 포함돼있다
        return lstm_out,hidden

# %%
class Decoder(nn.Module):
    def __init__(self,configs):
        super(Decoder,self).__init__()
        self.input_size = int(configs['1step_seq2seq']['input_size'])
        # input의 feature dimension을 넣어주어야 한다
        self.hidden_size = int(configs['1step_seq2seq']['hidden_size'])
        # 내부에서 feature dimension을 어떻게 바꿔주고 싶은지 넣어주면 된다
        # 가령 mxn matrix가 입력으로 들어왔을때 hidden size를 h라 한다면 mxh의 크기로 바꾼다
        self.num_layers = int(configs['1step_seq2seq']['num_layers'])
        self.lstm = nn.LSTM(input_size=self.input_size,hidden_size = self.hidden_size,
                           num_layers = self.num_layers,batch_first = True)
        self.linear = nn.Linear(self.hidden_size,self.input_size)
        
    def forward(self,x,encoder_hidden):

        lstm_out,_ = self.lstm(x,encoder_hidden)
        output = self.linear(lstm_out)
        
        return output,_
# 정리하자면 우리가 정답을 알고 있는 시점에서 1시점 전까지의 데이터를 encoder로 넣고
# 알고 있는 마지막시점 정보와 encoder에 넣어서 나온 hidden state를 넣어줌으로써 다음시점을 예측

# %%
class seq2seq(nn.Module):
    def __init__(self,configs):
        super(seq2seq,self).__init__()
        self.encoder = Encoder(configs)
        self.decoder = Decoder(configs)
        
    def forward(self,x):
        outputs = torch.zeros(x.size(0),1,1) # feature가1개고 target도 1개인 데이터
        _,final_hidden = self.encoder(x)
        output,_ = self.decoder(x = x[:,-1,:].view(-1,1,1),encoder_hidden = final_hidden)
        
        return output

# %%
def seq_data(x,sequence_length,pred_len):
    seq_list = []
    target_list = []
    device = torch.device("cuda:0")
    if (type(x)==list)|(type(x)==np.ndarray):
        for i in range(len(x)-sequence_length):
            seq_list.append(x[i:i+sequence_length].values)
            target_list.append(x[i+sequence_length])
    
    if (type(x) == pd.Series)|(type(x) == pd.DataFrame):
        for i in range(len(x)-sequence_length):
            seq_list.append(x.iloc[i:i+sequence_length].values)
            target_list.append(x.iloc[i+sequence_length])

#             if i == 0:
#                  print(x.iloc[i:i+sequence_length].values)
#                  print(y[i+sequence_length:i+sequence_length+pred_len].values)
            #print(x[i+sequence_length:i+sequence_length+pred_len].values.shape)
    else:
        print('error')

    return FloatTensor(seq_list).view(-1,1,sequence_length).to(device),FloatTensor(target_list).unsqueeze(1).view(-1,1,pred_len).to(device)

# %%
sequence_length = 1440
pred_len = 1
split= 10080
x_data = pd.DataFrame({'values':data[:-split].values.reshape(-1)})
x_seq,target = seq_data(x=x_data,sequence_length=sequence_length,pred_len=pred_len)

# %%
x_seq
# Out:
# tensor([[[0.8382, 0.8146, 0.8013,  ..., 0.8263, 0.8365, 0.8418]],
#
#         [[0.8146, 0.8013, 0.8039,  ..., 0.8365, 0.8418, 0.8420]],
#
#         [[0.8013, 0.8039, 0.7803,  ..., 0.8418, 0.8420, 0.8175]],
#
#         ...,
#
#         [[0.6584, 0.6867, 0.6864,  ..., 0.6986, 0.7334, 0.7053]],
#
#         [[0.6867, 0.6864, 0.7222,  ..., 0.7334, 0.7053, 0.7150]],
#
#         [[0.6864, 0.7222, 0.6899,  ..., 0.7053, 0.7150, 0.7057]]],
#        device='cuda:0')

# %%
import torch.optim as optim

# %%
device = torch.device('cuda:0')
batch_size = 32
num_epochs = 100
train_dataset = TensorDataset(x_seq,target)
training = DataLoader(train_dataset,batch_size=batch_size)
model = seq2seq(config).to(device)
optimizer = Adam(model.parameters(),1e-4)
criterion = SMAPE()
scheduler = optim.lr_scheduler.LambdaLR(optimizer=optimizer,
                                        lr_lambda=lambda epoch: 0.95 ** epoch,verbose = True)
                                       # epoch마다 learning rate에 곱해지는 값이 제곱수로 늘어남
# Out:
# Adjusting learning rate of group 0 to 1.0000e-04.

# %% [markdown]
# https://justkode.kr/deep-learning/pytorch-save <br>
# 모델 저장 및 불러오기

# %%
out_list = []
loss_list = []
n = len(training)
for i in range(num_epochs):
    running_loss = 0.0
    for seq,tg in training:
        
        seq = seq.permute(0,2,1)
        
        out = model(seq).to(device)
        
        loss = criterion(out,tg)
        
        optimizer.zero_grad()
        
        loss.backward()
        
        optimizer.step() # optimizer 최적화
        
        running_loss = running_loss + loss.item()        
    scheduler.step() #schedular update 
    loss_list.append(running_loss/n)
    print('smape',running_loss/n*100,'%')
# Out:
# Adjusting learning rate of group 0 to 9.5000e-05.
# smape 102.87322258522286 %
# Adjusting learning rate of group 0 to 9.0250e-05.
# smape 45.43358444339699 %
# Adjusting learning rate of group 0 to 8.5737e-05.
# smape 26.578610586056932 %
# Adjusting learning rate of group 0 to 8.1451e-05.
# smape 15.11570003711515 %
# Adjusting learning rate of group 0 to 7.7378e-05.
# smape 11.214371525753311 %
# Adjusting learning rate of group 0 to 7.3509e-05.
# smape 9.228018355495923 %
# Adjusting learning rate of group 0 to 6.9834e-05.
# smape 8.119607587666277 %
# Adjusting learning rate of group 0 to 6.6342e-05.
# smape 7.376003943449049 %
# Adjusting learning rate of group 0 to 6.3025e-05.
# smape 6.891711533603351 %
# Adjusting learning rate of group 0 to 5.9874e-05.
# smape 6.580851888229623 %
# Adjusting learning rate of group 0 to 5.6880e-05.
# smape 6.386796574255353 %
# Adjusting learning rate of group 0 to 5.4036e-05.
# smape 6.263972800116092 %
# Adjusting learning rate of group 0 to 5.1334e-05.
# smape 6.176523060880994 %
# Adjusting learning rate of group 0 to 4.8767e-05.
# smape 6.110887692489645 %
# Adjusting learning rate of group 0 to 4.6329e-05.
# smape 6.057296789452781 %
# Adjusting learning rate of group 0 to 4.4013e-05.
# smape 6.013290398421954 %
# Adjusting learning rate of group 0 to 4.1812e-05.
# smape 5.976247955004723 %
# Adjusting learning rate of group 0 to 3.9721e-05.
# smape 5.944240174000288 %
# Adjusting learning rate of group 0 to 3.7735e-05.
# smape 5.916196181662163 %
# Adjusting learning rate of group 0 to 3.5849e-05.
# smape 5.890060803602444 %
# Adjusting learning rate of group 0 to 3.4056e-05.
# smape 5.866858403536093 %
# Adjusting learning rate of group 0 to 3.2353e-05.
# smape 5.845980883701241 %
# Adjusting learning rate of group 0 to 3.0736e-05.
# smape 5.826882004890352 %
# Adjusting learning rate of group 0 to 2.9199e-05.
# smape 5.809169397880024 %
# Adjusting learning rate of group 0 to 2.7739e-05.
# smape 5.792782448983767 %
# Adjusting learning rate of group 0 to 2.6352e-05.
# smape 5.777638752274869 %
# Adjusting learning rate of group 0 to 2.5034e-05.
# smape 5.763525137710467 %
# Adjusting learning rate of group 0 to 2.3783e-05.
# smape 5.750084886360064 %
# Adjusting learning rate of group 0 to 2.2594e-05.
# smape 5.7376344094314335 %
# Adjusting learning rate of group 0 to 2.1464e-05.
# smape 5.726015329121323 %
# Adjusting learning rate of group 0 to 2.0391e-05.
# smape 5.715166265253871 %
# Adjusting learning rate of group 0 to 1.9371e-05.
# smape 5.7047379575669765 %
# Adjusting learning rate of group 0 to 1.8403e-05.
# smape 5.694970108966251 %
# Adjusting learning rate of group 0 to 1.7482e-05.
# smape 5.685724446343051 %
# Adjusting learning rate of group 0 to 1.6608e-05.
# smape 5.6769739759116495 %
# Adjusting learning rate of group 0 to 1.5778e-05.
# smape 5.66872913158929 %
# Adjusting learning rate of group 0 to 1.4989e-05.
# smape 5.660766261678777 %
# Adjusting learning rate of group 0 to 1.4240e-05.
# smape 5.653363426014432 %
# Adjusting learning rate of group 0 to 1.3528e-05.
# smape 5.646323098403494 %
# Adjusting learning rate of group 0 to 1.2851e-05.
# smape 5.639691931571354 %
# Adjusting learning rate of group 0 to 1.2209e-05.
# smape 5.6335232571333815 %
# Adjusting learning rate of group 0 to 1.1598e-05.
# smape 5.627690307872251 %
# Adjusting learning rate of group 0 to 1.1018e-05.
# smape 5.622060255893664 %
# Adjusting learning rate of group 0 to 1.0467e-05.
# smape 5.616760435214604 %
# Adjusting learning rate of group 0 to 9.9440e-06.
# smape 5.611711791253578 %
# Adjusting learning rate of group 0 to 9.4468e-06.
# smape 5.606929079536894 %
# Adjusting learning rate of group 0 to 8.9745e-06.
# smape 5.60237565731401 %
# Adjusting learning rate of group 0 to 8.5258e-06.
# smape 5.5980672976492265 %
# Adjusting learning rate of group 0 to 8.0995e-06.
# smape 5.594006999237844 %
# Adjusting learning rate of group 0 to 7.6945e-06.
# smape 5.590176838967535 %
# Adjusting learning rate of group 0 to 7.3098e-06.
# smape 5.586594004096866 %
# Adjusting learning rate of group 0 to 6.9443e-06.
# smape 5.5831215661345865 %
# Adjusting learning rate of group 0 to 6.5971e-06.
# smape 5.579843293080292 %
# Adjusting learning rate of group 0 to 6.2672e-06.
# smape 5.576733572473913 %
# Adjusting learning rate of group 0 to 5.9539e-06.
# smape 5.573781673355322 %
# Adjusting learning rate of group 0 to 5.6562e-06.
# smape 5.57099721982683 %
# Adjusting learning rate of group 0 to 5.3734e-06.
# smape 5.56834143226999 %
# Adjusting learning rate of group 0 to 5.1047e-06.
# smape 5.56583775942655 %
# Adjusting learning rate of group 0 to 4.8495e-06.
# smape 5.563444144348478 %
# Adjusting learning rate of group 0 to 4.6070e-06.
# smape 5.561189399433066 %
# Adjusting learning rate of group 0 to 4.3766e-06.
# smape 5.559042958292173 %
# Adjusting learning rate of group 0 to 4.1578e-06.
# smape 5.55702234193552 %
# Adjusting learning rate of group 0 to 3.9499e-06.
# smape 5.555080477671142 %
# Adjusting learning rate of group 0 to 3.7524e-06.
# smape 5.553232078598431 %
# Adjusting learning rate of group 0 to 3.5648e-06.
# smape 5.551489025615809 %
# Adjusting learning rate of group 0 to 3.3866e-06.
# smape 5.54983654081255 %
# Adjusting learning rate of group 0 to 3.2172e-06.
# smape 5.548255753142444 %
# Adjusting learning rate of group 0 to 3.0564e-06.
# smape 5.546764621935916 %
# Adjusting learning rate of group 0 to 2.9035e-06.
# smape 5.545345307191648 %
# Adjusting learning rate of group 0 to 2.7584e-06.
# smape 5.543998555220359 %
# Adjusting learning rate of group 0 to 2.6205e-06.
# smape 5.542717982922294 %
# Adjusting learning rate of group 0 to 2.4894e-06.
# smape 5.541506605604065 %
# Adjusting learning rate of group 0 to 2.3650e-06.
# smape 5.5403677832705585 %
# Adjusting learning rate of group 0 to 2.2467e-06.
# smape 5.539276071971185 %
# Adjusting learning rate of group 0 to 2.1344e-06.
# smape 5.538250542850348 %
# Adjusting learning rate of group 0 to 2.0277e-06.
# smape 5.537275649138797 %
# Adjusting learning rate of group 0 to 1.9263e-06.
# smape 5.5363444711642655 %
# Adjusting learning rate of group 0 to 1.8300e-06.
# smape 5.535460588691091 %
# Adjusting learning rate of group 0 to 1.7385e-06.
# smape 5.534615617964351 %
# Adjusting learning rate of group 0 to 1.6515e-06.
# smape 5.533824844438343 %
# Adjusting learning rate of group 0 to 1.5690e-06.
# smape 5.533059912172762 %
# Adjusting learning rate of group 0 to 1.4905e-06.
# smape 5.532345850652422 %
# Adjusting learning rate of group 0 to 1.4160e-06.
# smape 5.531665886757754 %
# Adjusting learning rate of group 0 to 1.3452e-06.
# smape 5.5310187443045145 %
# Adjusting learning rate of group 0 to 1.2779e-06.
# smape 5.530405632051372 %
# Adjusting learning rate of group 0 to 1.2140e-06.
# smape 5.529820907545107 %
# Adjusting learning rate of group 0 to 1.1533e-06.
# smape 5.5292664961726 %
# Adjusting learning rate of group 0 to 1.0957e-06.
# smape 5.528739438125352 %
# Adjusting learning rate of group 0 to 1.0409e-06.
# smape 5.528237271117188 %
# Adjusting learning rate of group 0 to 9.8884e-07.
# smape 5.527761403678192 %
# Adjusting learning rate of group 0 to 9.3939e-07.
# smape 5.527309818977589 %
# Adjusting learning rate of group 0 to 8.9242e-07.
# smape 5.526879090456325 %
# Adjusting learning rate of group 0 to 8.4780e-07.
# smape 5.526470403998481 %
# Adjusting learning rate of group 0 to 8.0541e-07.
# smape 5.526083261373708 %
# Adjusting learning rate of group 0 to 7.6514e-07.
# smape 5.525715440043319 %
# Adjusting learning rate of group 0 to 7.2689e-07.
# smape 5.525366439979676 %
# Adjusting learning rate of group 0 to 6.9054e-07.
# smape 5.5250349270495756 %
# Adjusting learning rate of group 0 to 6.5601e-07.
# smape 5.5247209247811675 %
# Adjusting learning rate of group 0 to 6.2321e-07.
# smape 5.524423676788023 %
# Adjusting learning rate of group 0 to 5.9205e-07.
# smape 5.52413934215424 %

# %%
device = torch.device('cuda:0')
X = data.iloc[:-split]
target = data.iloc[-split:]
pred_list = []
time_list = []
for idx in range(split):
    running_loss = 0.0
    start = time.time()
    if idx == 0:
        new_train = torch.FloatTensor(
        [X.iloc[-sequence_length:].values]).view(1,sequence_length,1).to(device)
                
    elif idx < sequence_length:
        new_train = torch.FloatTensor(
            [pd.concat([X.iloc[-sequence_length+idx:],target.iloc[0:idx]],axis=0,ignore_index=True).values]
            ).view(1,sequence_length,1).to(device)
    elif idx >= sequence_length:
        new_train = torch.FloatTensor(
            [target.iloc[idx-sequence_length:idx].values]
            ).view(1,sequence_length,1).to(device)

    with torch.no_grad():
        model.eval()
        out = model(new_train).to(device) # 예측완료
        end = time.time()
        pred_list.append(out.cpu().view(1).item())
        time_list.append(end-start)

# %%
len(pred_list)
# Out:
# 10080

# %%
target = target.values.reshape(-1,1)
score=SMAPE()(FloatTensor(np.array(pred_list).reshape(-1,1)),FloatTensor(target))*100
print('SMAPE',score.item(),'%')
# Out:
# SMAPE 4.069272994995117 %

# %%
fig,axes = plt.subplots(1,1,figsize=(12,8))
axes.plot(np.arange(1,10081),pred_list,label='prediction')

# %%
fig,axes = plt.subplots(1,1,figsize=(12,8))
axes.plot(np.arange(1,10081),pred_list,label='prediction')
axes.plot(np.arange(1,10081),target,label='target')
axes.legend()

# %%
fig,axes = plt.subplots(1,1,figsize=(12,8))
axes.plot(np.arange(1,61),pred_list[-60:],label='prediction')
axes.plot(np.arange(1,61),target[-60:],label='target')
axes.legend()

# %% [markdown]
# sliding이 됐음을 확인 할 수 있다

# %%
np.mean(time_list)
# Out:
# 0.0022231333785586887

# %% [markdown]
# <font color = blue><font size = 6> Conclusion </font></font><br>
# DLinear와 NLinear에 비해서 모델도 복잡하고 정확도도 떨어져서 RNN계열은 1step point forecasting에 적합하지 않은것으로 판단된다
